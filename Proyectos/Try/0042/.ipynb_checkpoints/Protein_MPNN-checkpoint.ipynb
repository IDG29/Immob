# %%
from bioprospecting import predictions
import bsc_calculations
import os
import re
import pandas as pd
import numpy as np

# %%
SetUp = predictions.proteinMPNN.setUPProteinMPNNCalculations(job_folder="ProMPNN_jobs", 
pdbs_folder="/home/idg29/BSC/Immob/Proyectos/Try/0042/PDB/PDB_Chain_Select/", score_only=True, ignore_residues=("HOH", "0D8", "12P", "144", "15P", "1GP", "1PC", "1PE", "1PG", "1WE", "1WF", "2M5", "2M9", "2PE", "3X9", "41M", "43Y", "44E", "44G", "4CC", "4HT", "4IB", "4NB", "4OO", "4TJ", "57S", "5CT", "6GN", "6GQ", "70E", "7GW", "7MT", "7V7", "88Q", "88T", "8EU", "8J8", "8SK", "91S", "9EG", "AB0", "ACE", "ACM", "ACT", "ACY", "AE2", "AE3", "AIC", "AML", "AN1", "ARF", "ATP", "AZI", "B40", "B41", "BCG", "BDU", "BEN", "BEZ", "BGC", "BMA", "BNG", "BPN", "BR", "BTB", "BTN", "BU2", "BU3", "BUD", "BZH", "CA", "CAC", "CAD", "CD", "CEQ", "CFF", "CIT", "CL", "CLM", "CLR", "CO", "CO3", "COC", "CPD", "CRO", "CRQ", "CS", "CSD", "CSO", "CSX", "CU", "CXS", "D3D", "DEP", "DGX", "DI", "DIK", "DMG", "DMS", "DO3", "DOE", "DOF", "DOG", "DV7", "E9R", "ECO", "EDO", "EDT", "END", "ENE", "ENH", "EOH", "EOT", "EPE", "EST", "ETE", "ETX", "FD0", "FE", "FLC", "FLU", "FME", "FMT", "FNZ", "FRA", "FTR", "FUC", "FUR", "FVP", "GA4", "GAS", "GD", "GD3", "GFN", "GLC", "GOL", "GSH", "H6P", "HAL", "HAN", "HAZ", "HBC", "HCY", "HD4", "HEP", "HG", "HIP", "HOP", "IAS", "IMD", "IOD", "IPA", "IPH", "IUM", "JEF", "K", "KDO", "KHA", "KO2", "KSD", "KW7", "LDA", "LHG", "LI", "LTX", "M3L", "M6P", "MAN", "MES", "MG", "MGS", "MLA", "MLI", "MLT", "MLY", "MMA", "MMP", "MN", "MOH", "MOI", "MPD", "MRY", "MSE", "MT1", "MTX", "NA", "NAG", "NCH", "NCO", "NCT", "NDG", "NDP", "NEP", "NES", "NGA", "NH4", "NHE", "NI", "NKN", "NLD", "NO3", "NO8", "NON", "NOX", "NP", "NPA", "NPC", "NPE", "NPO", "NPP", "NXD", "O2W", "O4B", "OA8", "OAB", "OAS", "OAZ", "OBE", "OBN", "OCS", "OCT", "OH", "OHM", "OLB", "OLC", "OM4", "OMF", "OOW", "OOX", "OS", "P0T", "P15", "P2E", "P33", "P4S", "P6G", "PB", "PC", "PCA", "PDO", "PE1", "PE4", "PE7", "PE8", "PEG", "PEU", "PG0", "PG4", "PG5", "PG6", "PGE", "PHX", "PIE", "PNB", "PNE", "PNP", "PO4", "POV", "QI9", "RAC", "RAM", "RBF", "RR6", "S1P", "SCN", "SEP", "SH4", "SIA", "SIN", "SO4", "SPB", "STG", "T5C", "TAA", "TAM", "TAR", "TB", "TCE", "TES", "TI0", "TIQ", "TK4", "TLA", "TMO", "TNS", "TOE", "TOP", "TPM", "TPO", "TRS", "TRZ", "TSA", "TUA", "TYS", "UGZ", "UNL", "UNX", "URE", "XOP", "Y01", "Y4K", "Y4Q", "YCM", "YT3", "YTZ", "YYJ", "ZN", "UNK"))

# %%
jobs = bsc_calculations.local.multipleGPUSimulations(SetUp, gpus=2)

# %%
a = predictions.proteinMPNN.readScoresToDataFrame(output_folder="/home/idg29/BSC/Immob/Proyectos/Try/0042/ProMPNN_jobs", return_missing_files=True)

# %%
# Locate the output directory
output_folder="/home/idg29/BSC/Immob/Proyectos/Try/0042/ProMPNN_jobs"
output_path = os.path.join(output_folder, "output")

if not os.path.exists(output_path):
    raise ValueError(f"The folder 'output' was not found in {output_folder}")

# Iterate over model subfolders in the output directory
metadata = {}
pdb_name_list = []
chains_list = []
score_list = []
global_score_list = []
for model_folder in os.listdir(output_path):
    model_path = os.path.join(output_path, model_folder)
    seq_path = os.path.join(model_path, f"seqs/{model_folder}.fa")

    
    
    with open(seq_path) as f:
        lines = f.readlines()
    
        for line in lines:
            line = line.strip()
            
            if re.match(r"^>\d+", line):
                pdb_name = (line.split(","))[0]
                pdb_name_list.append(pdb_name)
                designed_chains = (line.split(","))[4]
                chains_list.append(designed_chains)
                score = float(((line.split(","))[1]).split("=")[1])
                score_list.append(score)
                global_score = float(((line.split(","))[2]).split("=")[1])
                global_score_list.append(global_score)
            
                metadata[pdb_name] = {
                    "score" : score,
                    "global_score" : global_score
                    
                }


data = {
    "pdb_name" : pdb_name_list,
    "chain" : chains_list,
    "score" : score_list,
    "global_score" : global_score_list   
}

df = pd.DataFrame(data)
df.replace(to_replace="nan", value=np.nan, inplace=True )
df.dropna(inplace=True)
df.sort_values(by="score", ascending=False)
# Out:
#       pdb_name                   chain   score  global_score
# 1429   >7OMT_A   designed_chains=['A']  0.7060        0.7060
# 6107   >4EDQ_B   designed_chains=['B']  0.7543        0.7543
# 6140   >3OAI_B   designed_chains=['B']  0.8610        0.8610
# 5154   >6SWR_D   designed_chains=['D']  0.9563        0.9563
# 8708   >4PFE_A   designed_chains=['A']  1.0215        1.0215
# ...        ...                     ...     ...           ...
# 8531   >6W09_P   designed_chains=['P']  2.7938        2.7938
# 1824   >7LD1_L   designed_chains=['L']  2.7941        2.7941
# 8732   >7LD1_P   designed_chains=['P']  2.8306        2.8306
# 8431   >7LD1_O   designed_chains=['O']  2.8690        2.8690
# 10130  >7SG4_L   designed_chains=['L']  2.8985        2.8985
#
# [11544 rows x 4 columns]

# %%
df["score"].mean()
# Out:
# 1.5432860013860012

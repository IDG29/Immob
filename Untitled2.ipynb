# %%
import pandas as pd
import os

# %%
dir_file = "/home/ivan/BSC/Immob/docking/output_models/GPX_Bacillus-subtilis/GPX_Bacillus-subtilis_GSH.csv"

# %%
df = pd.read_csv(dir_file)

# %%
df
# Out:
#                                                SMILES  title  \
# 0   N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 1   N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 2   N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 3   N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 4   N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# ..                                                ...    ...
# 94  N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 95  N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 96  N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 97  N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
# 98  N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)[O-])C(=...    NaN
#
#     i_i_glide_lignum docking_status  r_glide_cpu_time  r_i_docking_score  \
# 0                  1           Done             19.80           -3.94232
# 1                  1           Done             19.80           -3.83315
# ...

# %%
columnas = ["s_i_glide_gridfile", "r_i_glide_gscore"]
datos = df[columnas]

# %%
datos.sort_values(by=["r_i_glide_gscore"])
# Out:
#        s_i_glide_gridfile  r_i_glide_gscore
# 5   GPX_Bacillus-subtilis          -4.19249
# 0   GPX_Bacillus-subtilis          -3.94232
# 8   GPX_Bacillus-subtilis          -3.92602
# 13  GPX_Bacillus-subtilis          -3.87667
# 10  GPX_Bacillus-subtilis          -3.86405
# ..                    ...               ...
# 96  GPX_Bacillus-subtilis          -2.20575
# 88  GPX_Bacillus-subtilis          -2.14827
# 94  GPX_Bacillus-subtilis          -2.04177
# 95  GPX_Bacillus-subtilis          -1.95052
# 97  GPX_Bacillus-subtilis          -1.91398
#
# [99 rows x 2 columns]
